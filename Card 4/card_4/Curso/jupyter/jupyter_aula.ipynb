# %%
print('hello')   # shift + enter salva e roda a célula
# alt + enter cria uma linha abaixo
# em run > restart kernel eu volto o kernel pro início

# %%
a = 1
print(a)

# %%
# criei essa célula com alt + enter só pra testar o atalho

# %%
print('hello')

# %%
print(a)   # ainda funciona, o kernel guardou o valor da célula de cima

# %%
print('Ola')   # sempre olho se a escrita tá colorida, se não tiver é markdown e não roda
