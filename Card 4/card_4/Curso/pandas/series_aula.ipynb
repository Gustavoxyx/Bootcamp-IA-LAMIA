# %%
import numpy as np
import pandas as pd

# %%
labels = ['a', 'b', 'c']

# %%
minha_lista = [10, 20, 30]
arr = np.array([10, 20 ,30])
d = {'a' : 10, 'b' : 20, 'c' : 30}

# %%
pd.Series(data=minha_lista, index=labels)   # em data ponho os valores em index a forma de navegar

# %%
series = pd.Series(data=minha_lista, index=labels)

# %%
series['b']   # busco pelo rótulo parecido com dicionário

# %%
pd.Series(minha_lista, labels)   # dá pra passar na ordem sem escrever data e index

# %%
pd.Series(arr, labels)   # aceito vários tipos de dado aqui um array do numpy

# %%
ser1 = pd.Series([1, 2, 3, 4], index=['EUA', 'Alemanha', 'URSS', 'Japão'])

# %%
ser1

# %%
ser2 = pd.Series([1, 2, 3, 4], index=['Alemanha', 'EUA', 'Itália', 'Japão'])

# %%
ser2

# %%
ser1 + ser2   # a Series faz a conta pelo índice e não pela posição
              # quem só existe num dos lados vira nan
