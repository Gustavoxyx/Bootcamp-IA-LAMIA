# %%
import pandas as pd
import numpy as np

# %%
# %pip install openpyxl
# %pip install lxml

# %%
df = pd.read_csv('exemplo.csv', sep=',')   # o pandas não olha a extensão do arquivo,
                                       # quem manda é o metodo que chamo e não o nome
df

# %%
df - df + 1   # a conta vale pra tabela inteira elemento por elemento

# %%
df.to_csv('exemplo.csv', sep=';', decimal=',')   # planilha feita no brasil usa ; na coluna e no decimal

# %%
df = pd.read_excel('Exemplo_Excel.xlsx', sheet_name='Sheet1')   # em sheet_name escolho a aba
                                                                # pro excel preciso que o openpyxl esteja instalado

# %%
df.to_excel('exemplo.xlsx', sheet_name='Sheet1')

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')
# o read_html puxa as tabelas de uma página aqui eu vou precisar de internet e do lxml pra funcioanr
# ele devolve uma lista de tabelas

# %%
df[0]   # por ser lista acesso a primeira tabela com [0]
