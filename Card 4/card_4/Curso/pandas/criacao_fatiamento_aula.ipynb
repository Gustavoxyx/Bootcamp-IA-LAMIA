# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(101)   # travo o sorteio

# %%
df = pd.DataFrame(np.random.randn(5,4), index= 'A B C D E'.split(), columns = 'W X Y Z'.split())
df

# %%
df['W']   # pego uma coluna

# %%
type(df['W'])   # coluna sozinha volta como Series

# %%
type(df)

# %%
df[['W', 'Z']]   # com lista dentro do colchete volta como dataframe

# %%
df.W   # atalho com ponto mas quebra se o nome tem espaço ou bate com metodo do pandas

# %%
df['new'] = df['W'] + df['X']   # crio coluna atribuindo num nome que não existe
df

# %%
df.drop('new', axis=1)   # axis=1 é coluna axis 0 é linha

# %%
df   # a coluna continua aí sem o inplace ele só me devolve uma cópia alterada

# %%
df.drop('new', axis=1, inplace=True)   # com inplace altero o original de verdade
df

# %%
df.loc['A', 'W']   # com loc faço seleção pelo rótulo aqui linha A coluna W

# %%
df.loc['A']   # a linha A inteira

# %%
df.loc[['A', 'B'], ['X', 'Y', 'Z']]   # recorto passando listas de rótulo

# %%
df.iloc[1:4, 2:]   # o iloc é por posicao que nem no numpy
