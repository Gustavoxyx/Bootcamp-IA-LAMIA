# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1

# %%
df2

# %%
df3

# %%
pd.concat([df1, df2, df3])   # pra unir uso axis 0 que empilha pra baixo somando linha
                             # o axis 1 cresce pro lado somando coluna

# %%
pd.concat([df1, df2, df3], axis=1)   # ficou bugado por conta dos índices não baterem,
                                     # por isso tenho que pensar bem nos idx antes de concatenar

# %%
esquerda = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

direita = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
esquerda

# %%
direita

# %%
pd.merge(esquerda,direita,how='inner',on='key')   # o inner mantém só o que tem igual nos dois

# %%
esquerda = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})

direita = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(esquerda, direita, on=['key1', 'key2'])   # com lista no on eu exijo que todas as chaves batam

# %%
pd.merge(esquerda, direita, how='outer', on=['key1', 'key2'])   # o outer coloca todos e bota nan nos que não existem

# %%
pd.merge(esquerda, direita, how='right', on=['key1', 'key2'])   # o right mantém todas as da direita
                                                                # e bota nan onde a esquerda não tem par

# %%
pd.merge(esquerda, direita, how='left', on=['key1', 'key2'])   # o left é o contrário mantém todas as da esquerda

# %%
esquerda = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2'])

direita = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
esquerda

# %%
direita

# %%
esquerda.join(direita)   # o join faz a junção pelo indice o padrão dele é how left

# %%
esquerda.join(direita, how='outer')   # manteve todos os dois lados
